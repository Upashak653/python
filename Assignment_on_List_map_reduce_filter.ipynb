# %% [markdown]
# 1)What is the difference between a function and a method in Python?
# - function inside a class is known as method , it is a function that is associated with an object (class instance).A function in Python is a block of reusable code defined using the def keyword (or lambda for anonymous functions).

# %% [markdown]
# 2) Explain the concept of function arguments and parameters in Python?
# - Parameters are the variables defined in the function signature (the definition).They act as placeholders for the values the function will receive.
# - Arguments are the actual values/data you pass to a function when calling it.

# %% [markdown]
# 3) What are the different ways to define and call a function in Python?
# - Standard function defination
# - Function with default parameters
# - Functions with *args,**kwargs
# - using Lambda
# - using map,filter,reduce function
# - using method
# - recursive function

# %% [markdown]
# 4)What is the purpose of the `return` statement in a Python function?
# - in function the return statement returns the output of the function from where it is called .Can return single,multiple or none values

# %% [markdown]
# 5)What are iterators in Python and how do they differ from iterables?
# - iterator is the object which performs the iteration, one item at a time.Must implement 2 methods iter() and next().
# -iterables are the datatypes that can be iterable using loops

# %% [markdown]
# 6) Explain the concept of generators in Python and how they are defined.
# - standard function,iterators uses return which returns the output after exectuing the code which consumes time and more memory , where as generator returns the output one by one ,special type of iterator which generates the output lazily,and don't store any kind of memory
# - define:
#         def gen(n):
#           for i in range(n):
#             yield i
#         generator = gen(5)
#         print(next(generator))

# %% [markdown]
# 7) What are the advantages of using generators over regular functions?
# - generators consumes lesser memory regular function uses more memory
# - they automatically returns one my one output,regular function returns the whole output after execution

# %% [markdown]
# 8)What is a lambda function in Python and when is it typically used?
#  - an anonymous function which is used to call functions without using def
#  - lambda arguments: expression

# %% [markdown]
# 9) Explain the purpose and usage of the `map()` function in Python.
# - it applies the specified function to every items of a given iterable(list,tuple etc.)
# - list (map(function, iterable))

# %% [markdown]
# 10)What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# - map function : it applies the specified function to every items of a given iterable(list,tuple etc.)
# - filter function : it filters the specified expression to every items of a given iterable(list,tuple etc.)
# - reduce function : Reduces all items in an iterable to a single value using a binary function

# %% [markdown]
# 11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given list [47,11,42,13]
# - ![11.jpg](data:image/jpeg;base64,...)

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list
def add(li):
 s=0
 for i in li:
  s=s+i
 return s
li=[1,2,3,4]
add(li)
# Out:
# 10

# %%
#. Create a Python function that accepts a string and returns the reverse of that string
def rev(s):
  return s[::-1]
rev("Hello")
# Out:
# 'olleH'

# %%
# Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def sq(li):
  sq=[]
  for i in li:
    sq.append(i**2)
  return sq
print(sq([1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
# Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n: int) -> bool:
    """Check if a number is prime."""
    if n <= 1:
        return False
    if n == 2:
        return True
    if n % 2 == 0:
        return False

    for i in range(3, int(n**0.5) + 1, 2):
        if n % i == 0:
            return False
    return True


for num in range(1, 201):
    print(f"{num} is prime: {is_prime(num)}")
# Out:
# 1 is prime: False
# 2 is prime: True
# 3 is prime: True
# 4 is prime: False
# 5 is prime: True
# 6 is prime: False
# 7 is prime: True
# 8 is prime: False
# 9 is prime: False
# 10 is prime: False
# 11 is prime: True
# 12 is prime: False
# 13 is prime: True
# 14 is prime: False
# 15 is prime: False
# 16 is prime: False
# 17 is prime: True
# 18 is prime: False
# 19 is prime: True
# 20 is prime: False
# 21 is prime: False
# 22 is prime: False
# 23 is prime: True
# 24 is prime: False
# 25 is prime: False
# 26 is prime: False
# 27 is prime: False
# 28 is prime: False
# 29 is prime: True
# 30 is prime: False
# 31 is prime: True
# 32 is prime: False
# 33 is prime: False
# 34 is prime: False
# 35 is prime: False
# 36 is prime: False
# 37 is prime: True
# 38 is prime: False
# 39 is prime: False
# 40 is prime: False
# 41 is prime: True
# 42 is prime: False
# 43 is prime: True
# 44 is prime: False
# 45 is prime: False
# 46 is prime: False
# 47 is prime: True
# 48 is prime: False
# ...

# %%
# Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
def fib(n):
  a, b = 0, 1
  series = []
  for _ in range(n):
        series.append(a)
        a, b = b, a + b
  return series
n=int(input("Enter the number of terms: "))
print(fib(n))
it=iter(fib(n))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# Enter the number of terms: 6
# [0, 1, 1, 2, 3, 5]
# 0
# 1
# 1
# 2
# 3

# %%
# Write a generator function in Python that yields the powers of 2 up to a given exponent.
def gen(n):
  for i in range(n):
   yield i**2
n=int(input("Enter the number of terms: "))
generator=gen(n)
for i in range(n):
  print(next(generator))
# Out:
# Enter the number of terms: 5
# 0
# 1
# 4
# 9
# 16

# %%
#. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line
line=read_file("data.txt")
for i in line:
  print(i)
# Out:
# Machine learning approaches are traditionally divided into three broad categories, which correspond to learning paradigms, depending on the nature of the "signal" or "feedback" available to the learning system:

# %%
#Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
li=[("Sachin Tendulkar", 34357), ("Ricky Ponting", 27483), ("Jack Kallis", 25534), ("Virat Kohli", 24936)]
sorted(li,key=lambda x:x[1])
# Out:
# [('Virat Kohli', 24936),
#  ('Jack Kallis', 25534),
#  ('Ricky Ponting', 27483),
#  ('Sachin Tendulkar', 34357)]

# %%
#Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
li=[32,64,96]
def temp(x):
  return ((9*x//5)+32)

list(map(temp,li))
# Out:
# [89, 147, 204]

# %%
# Create a Python program that uses `filter()` to remove all the vowels from a given string
str=input()
vowels = "aeiouAEIOU"
list(filter(lambda x: x not in vowels,str ))
# Out:
# Upashak
# ['p', 's', 'h', 'k']

# %%
orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]

result = list(map(
    lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10),
    orders
))

print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
